# %% [markdown]
# **de xml/ALTO à xml/TEI**
#
# Script modifié pour fonctionner sur google-colab

# %% [markdown]
# Setup Googledrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. Télécharger les scriptes

# %%
# !git clone https://github.com/16thExegesisDH/Notebooks
# Out:
# Cloning into 'Notebooks'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 165 (delta 7), reused 162 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (165/165), 180.46 KiB | 1.28 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# 1.2 garder les dossiers pertients et supprimer les autres

# %%
# !rm -rf /content/Notebooks/normalisation/
# !rm -rf /content/Notebooks/xml_format/
# !rm -rf /content/Notebooks/.git/
# !rm  /content/Notebooks/README.md

# %% [markdown]
# 2. configurer les emplacements des dossiers

# %%
# !mkdir /content/Notebooks/alto2tei/content/data/
# !mkdir /content/Notebooks/alto2tei/content/data/doc_1/

# %% [markdown]
# 3. telécharger les données à traiter

# %%
! git clone https://github.com/16thExegesisDH/HTR-Corpus-C
# Out:
# Cloning into 'HTR-Corpus-C'...
# remote: Enumerating objects: 7711, done.
# remote: Counting objects: 100% (1302/1302), done.
# remote: Compressing objects: 100% (956/956), done.
# remote: Total 7711 (delta 499), reused 974 (delta 344), pack-reused 6409 (from 4)
# Receiving objects: 100% (7711/7711), 1.47 GiB | 32.08 MiB/s, done.
# Resolving deltas: 100% (1853/1853), done.
# Updating files: 100% (5154/5154), done.

# %% [markdown]
# :4. copy et déplacer les données concernées
# changer le chemin en fonction du dossier sur lequel on travail ici : **Bugenhagen_rm.**

# %%
# !cp /content/HTR-Corpus-C/data/Bugenhagen_rm/*.xml /content/Notebooks/alto2tei/content/data/doc_1/

# %% [markdown]
# 5. supprimer le dépôt

# %%
! rm -rf /content/HTR-Corpus-C

# %%
#!python content/scripts/alto2tei.py --config content/config.yml --version "4.1.3" --header --sourcedoc --body
# !python /content/Notebooks/alto2tei/content/scripts/alto2tei.py --config /content/Notebooks/alto2tei/content/config.yml --version "4.1.3" --header --sourcedoc --body
# Out:
# /content/Notebooks/alto2tei/content/scripts/src/order_files.py:16: SyntaxWarning: invalid escape sequence '\d'
#   ordered_files = sorted([File(int(re.search(r"(\d+).xml$", f.name).group(1)), f)for f in self.fl])
# It starts
# Doc being processed
#
# ...
# ~ now processing document doc_1 ~
# building <teiHeader>
# |________finished in 0.2018 seconds
# building <sourceDoc>
# Skipping file (no match): METS.xml
# |________finished in 4.0938 seconds
# building <body>
# |________finished in 0.1631 seconds
# We save the file.

# %% [markdown]
# download le nouveau fichier

# %%
# download lematized.zip

from google.colab import files
files.download('/content/Notebooks/alto2tei/content/data/doc_1.xml')

# %% [markdown]
# ***nettoyage***
# * effacer les anciennes données

# %%
# !rm /content/Notebooks/alto2tei/content/data/doc_1.xml
# !rm /content/Notebooks/alto2tei/content/data/doc_1/*.xml

# %% [markdown]
# * effacer le dépôt

# %%
# !rm -rf /content/Notebooks/
